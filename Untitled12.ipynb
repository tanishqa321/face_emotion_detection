# Reusing existing connection to uc7b41b6f5760a3c05554bd07144.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 63252113 (60M) [application/zip]
# Saving to: ‘dataset.zip?dl=0’
#
# dataset.zip?dl=0    100%[===================>]  60.32M  59.7MB/s    in 1.0s
#
# 2024-05-22 19:43:57 (59.7 MB/s) - ‘dataset.zip?dl=0’ saved [63252113/63252113]

# %%
# !unzip dataset.zip?dl=0
# Out:
# Archive:  dataset.zip?dl=0
# replace test/angry/PrivateTest_10131363.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace test/angry/PrivateTest_10304478.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace test/angry/PrivateTest_1054527.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input
from keras.losses import categorical_crossentropy

# %%
base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2,
     shear_range = 0.2,
     horizontal_flip=True,
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "/content/train",
                                               target_size=(224,224),
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 28726 images belonging to 7 classes.
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "/content/test",
                                           target_size=(224,224),
                                           batch_size=32,
                                  )
# Out:
# Found 7178 images belonging to 7 classes.

# %%
t_img , label = train_data.next()


def plotImages(img_arr, label):
  """
  input  :- images array
  output :- plots the images
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()

    count += 1
    if count == 10:
      break

plotImages(t_img, label)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data,
                           steps_per_epoch= 10,
                           epochs= 30,
                           validation_data= val_data,
                           validation_steps= 8,
                           callbacks=[es,mc])
# Out:
# <ipython-input-20-7dbb6b2d1ed1>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 18.8001 - accuracy: 0.2219
# Epoch 1: val_accuracy improved from -inf to 0.29297, saving model to best_model.h5
# 10/10 [==============================] - 31s 3s/step - loss: 18.8001 - accuracy: 0.2219 - val_loss: 16.2191 - val_accuracy: 0.2930
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 13.7143 - accuracy: 0.3000
# Epoch 2: val_accuracy improved from 0.29297 to 0.31250, saving model to best_model.h5
# 10/10 [==============================] - 27s 3s/step - loss: 13.7143 - accuracy: 0.3000 - val_loss: 8.3426 - val_accuracy: 0.3125
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 8.8532 - accuracy: 0.3250
# Epoch 3: val_accuracy improved from 0.31250 to 0.34766, saving model to best_model.h5
# 10/10 [==============================] - 37s 4s/step - loss: 8.8532 - accuracy: 0.3250 - val_loss: 8.9313 - val_accuracy: 0.3477
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 7.6885 - accuracy: 0.3781
# Epoch 4: val_accuracy did not improve from 0.34766
# 10/10 [==============================] - 27s 3s/step - loss: 7.6885 - accuracy: 0.3781 - val_loss: 8.3829 - val_accuracy: 0.3242
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 6.9565 - accuracy: 0.3500
# Epoch 5: val_accuracy improved from 0.34766 to 0.41797, saving model to best_model.h5
# 10/10 [==============================] - 37s 4s/step - loss: 6.9565 - accuracy: 0.3500 - val_loss: 5.2912 - val_accuracy: 0.4180
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 6.3096 - accuracy: 0.4062
# Epoch 6: val_accuracy did not improve from 0.41797
# 10/10 [==============================] - 26s 3s/step - loss: 6.3096 - accuracy: 0.4062 - val_loss: 5.0442 - val_accuracy: 0.4023
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 5.3444 - accuracy: 0.4187
# Epoch 7: val_accuracy did not improve from 0.41797
# 10/10 [==============================] - 25s 3s/step - loss: 5.3444 - accuracy: 0.4187 - val_loss: 6.7177 - val_accuracy: 0.3438
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 6.0254 - accuracy: 0.3844
# Epoch 8: val_accuracy did not improve from 0.41797
# 10/10 [==============================] - 37s 4s/step - loss: 6.0254 - accuracy: 0.3844 - val_loss: 6.2452 - val_accuracy: 0.3398
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 5.7424 - accuracy: 0.4000
# Epoch 9: val_accuracy improved from 0.41797 to 0.42578, saving model to best_model.h5
# 10/10 [==============================] - 27s 3s/step - loss: 5.7424 - accuracy: 0.4000 - val_loss: 5.1753 - val_accuracy: 0.4258
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 5.4596 - accuracy: 0.4125
# Epoch 10: val_accuracy improved from 0.42578 to 0.42969, saving model to best_model.h5
# 10/10 [==============================] - 27s 3s/step - loss: 5.4596 - accuracy: 0.4125 - val_loss: 4.8406 - val_accuracy: 0.4297
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 5.5314 - accuracy: 0.4156
# Epoch 11: val_accuracy improved from 0.42969 to 0.50000, saving model to best_model.h5
# 10/10 [==============================] - 37s 4s/step - loss: 5.5314 - accuracy: 0.4156 - val_loss: 4.2166 - val_accuracy: 0.5000
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 5.5724 - accuracy: 0.4563
# Epoch 12: val_accuracy did not improve from 0.50000
# 10/10 [==============================] - 27s 3s/step - loss: 5.5724 - accuracy: 0.4563 - val_loss: 6.1884 - val_accuracy: 0.4375
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 5.7568 - accuracy: 0.4031
# Epoch 13: val_accuracy did not improve from 0.50000
# 10/10 [==============================] - 37s 4s/step - loss: 5.7568 - accuracy: 0.4031 - val_loss: 6.2575 - val_accuracy: 0.4258
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 4.9941 - accuracy: 0.4625
# Epoch 14: val_accuracy did not improve from 0.50000
# 10/10 [==============================] - 36s 4s/step - loss: 4.9941 - accuracy: 0.4625 - val_loss: 5.1144 - val_accuracy: 0.4180
# Epoch 15/30
# 10/10 [==============================] - ETA: 0s - loss: 4.5695 - accuracy: 0.4969
# Epoch 15: val_accuracy did not improve from 0.50000
# 10/10 [==============================] - 35s 4s/step - loss: 4.5695 - accuracy: 0.4969 - val_loss: 4.3818 - val_accuracy: 0.4531
# Epoch 16/30
# 10/10 [==============================] - ETA: 0s - loss: 5.7510 - accuracy: 0.4656
# Epoch 16: val_accuracy did not improve from 0.50000
# 10/10 [==============================] - 28s 3s/step - loss: 5.7510 - accuracy: 0.4656 - val_loss: 6.8247 - val_accuracy: 0.3828
# Epoch 16: early stopping

# %%
from keras.models import load_model
model = load_model("/content/best_model.h5")

# %%
h =  hist.history
h.keys()
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))
path = "/content/train/sad/Training_10022789.jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 0s 53ms/step
#  the image is of sad
